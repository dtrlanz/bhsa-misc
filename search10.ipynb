# %%
from tf.app import use
A = use('bhsa')
F = A.TF.api.F
# Out:
# <b title="local release">TF-app:</b> <span title="rv2.3.0=#113c0687cfce3077734dac1844d244d20f4ace6f offline under ~/text-fabric-data">C:\Users\ittai_n0vs94x/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6=#bac4a9f5a2bbdede96ba6caea45e762fe88f88c5 offline under ~/text-fabric-data">C:\Users\ittai_n0vs94x/text-fabric-data/etcbc/bhsa/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2=#1ac68e976ee4a7f23eb6bb4c6f401a033d0ec169 offline under ~/text-fabric-data">C:\Users\ittai_n0vs94x/text-fabric-data/etcbc/phono/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2=#395dfe2cb69c261862fab9f0289e594a52121d5c offline under ~/text-fabric-data">C:\Users\ittai_n0vs94x/text-fabric-data/etcbc/parallels/tf/c</span>
# This is Text-Fabric 9.0.0
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 120 features found and 0 ignored
# ...

# %%
A.table(A.search('''
book book=Samuel_I|Samuel_II
    sentence
        word sp=verb vt=impf
    <: sentence
        word lex_utf8=ו 
        <: word sp=verb vt=perf
'''))
# Out:
#   1.35s 96 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">sentence</th><th class="tf">word</th><th class="tf">sentence</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
book book=Samuel_I|Samuel_II
    sentence
        word lex_utf8=ו 
        <: word sp=verb vt=impf
'''))
# Out:
#   0.83s 105 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">sentence</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
lex freq_lex=70
'''))
# Out:
#   0.01s 6 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">lex</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1DNn" title="Show this on SHEBANQ"><span title="voc_lex_utf8">דָּן</span></a></span></td><td class="tf rtl"><span class="rtl ubd"></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead ltr"><a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1LJNv" title="Show this on SHEBANQ"><span title="voc_lex_utf8">לין</span></a></span></td><td class="tf rtl"><span class="rtl ubd"></span></td></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=נשׂא vs=qal vt=wayq|impf gn=f nu=pl
'''))
# Out:
#   0.39s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=9&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Jeremiah 9:17">Jeremiah 9:17</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="plain rtl  hl" ><span class="txtu hbo">תִשֶּׂ֥נָה </span></span><span class="txtu hbo">עָלֵ֖ינוּ </span><span class="txtu hbo">נֶ֑הִי </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">תִשֶּׂ֥נָה </span></span></span></td></tr>
# ...

# %% [markdown]
# # Qatal 2nd f. sg. for verbs ending in ח or ע
# Qal stem only

# %%
A.table(A.search('''
clause
    word lex_utf8~[חע]$ nu=sg gn=f ps=p2 vt=perf vs=qal
'''))
# Out:
#   0.39s 28 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=1&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="1_Kings 1:11">1_Kings 1:11</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">הֲ</span><span class="txtu hbo">לֹ֣וא </span><span class="plain rtl  hl" ><span class="txtu hbo">שָׁמַ֔עַתְּ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">שָׁמַ֔עַתְּ </span></span></span></td></tr>
# ...

# %% [markdown]
# # Verb III-א except בוא occuring >69 times

# %%
A.table(A.search('''
clause
    w:word lex_utf8~א$ vs=qal vt=impf|wayq
    v:word lex_utf8#בוא
w = v
l:lex freq_lex>69
w ]] l
''')[0:10])
# Out:
#   0.84s 1446 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">lex</th></tr>
# ...

# %%
A.table(A.search('''
clause
    w:word lex_utf8~ה$ vs=qal vt=ptca nu=pl st=a prs=absent
    v:word lex_utf8#היה|ראה
w = v
l:lex freq_lex>69
w ]] l
''')[0:10])
# Out:
#   0.87s 178 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">lex</th></tr>
# ...

# %%
A.table(A.search('''
book book=Genesis
    # %word freq_lex<70
    verse 
''')[0:10])
# Out:
#   0.03s 1533 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">verse</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="txtu hbo rtl"><span class="tfsechead">Genesis</span></span></span></td><td class="tf rtl"><span class="rtl ubd"></span></td></tr>
# ...

# %%
A.table(A.search('''
clause
    w:word lex_utf8~ה$ lex_utf8=קום|שׁוב|בושׁ|מות vs=qal vt=wayq nu=pl ps=p1
    # %v:word lex_utf8#היה|ראה
# %w = v
l:lex 
w ]] l
''')[0:500])
# Out:
#   0.35s 1 result
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">lex</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=חנן vs=qal vt=perf ps=p1|p2
''')[0:22])
# Out:
#   0.35s 2 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=33&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Exodus 33:19">Exodus 33:19</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="plain rtl  hl" ><span class="txtu hbo">חַנֹּתִי֙ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">חַנֹּתִי֙ </span></span></span></td></tr>
# ...

# %%
A.table(A.search('''
lex
/with/
    word vs=piel lex_utf8~.[וי].
    word vs=pual
    word vs=hit
/-/
''')[0:22])
# Out:
#   1.13s 4 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">lex</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1RWMv" title="Show this on SHEBANQ"><span title="voc_lex_utf8">רום</span></a></span></td><td class="tf rtl"><span class="rtl ubd"></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead ltr"><a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KWNv" title="Show this on SHEBANQ"><span title="voc_lex_utf8">כון</span></a></span></td><td class="tf rtl"><span class="rtl ubd"></span></td></tr>
# ...

# %%
A.table(A.search('''
clause
    word sp=verb vs=poel
''')[0:22])
# Out:
#   0.41s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Jesaia&amp;chapter=10&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Isaiah 10:13">Isaiah 10:13</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וַ</span><span class="txtu hbo">עֲתוּדֹֽותֵיהֶם֙ </span><span class="plain rtl  hl" ><span class="txtu hbo">שֹׁושֵׂ֔תִי </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">שֹׁושֵׂ֔תִי </span></span></span></td></tr>
# ...

# %%
A.table(A.search('''
clause
    word sp=verb vs=poal
''')[0:22])
# Out:
#   0.39s 3 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word sp=verb vs=htpo
''')[0:22])
# Out:
#   0.40s 3 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word sp=verb lex_utf8=שׂמאל
''')[0:22])
# Out:
#   0.34s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=13&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 13:9">Genesis 13:9</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="plain rtl  hl" ><span class="txtu hbo">אַשְׂמְאִֽילָה׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">אַשְׂמְאִֽילָה׃ </span></span></span></td></tr>
# ...

# %%
A.table(A.search('''
clause
    word sp=verb lex_utf8=שׁמע vs=qal vt=impf prs_ps=p1|p2|p3
''')[0:22])
# Out:
#   0.35s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=6&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Exodus 6:12">Exodus 6:12</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="txtu hbo">אֵיךְ֙ </span><span class="plain rtl  hl" ><span class="txtu hbo">יִשְׁמָעֵ֣נִי </span></span><span class="txtu hbo">פַרְעֹ֔ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">יִשְׁמָעֵ֣נִי </span></span></span></td></tr>
# ...

# %%
A.table(A.search('''
clause
    # %word sp=verb vs=qal vt=impf ps=p3 nu=sg prs_ps=p3 prs_gn=f
    word sp=verb vs=qal vt=perf ps=p3 nu=pl prs_ps=p3 prs_gn=m
''')[0:20])
# Out:
#   0.41s 60 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=15&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 15:13">Genesis 15:13</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וַ</span><span class="plain rtl  hl" ><span class="txtu hbo">עֲבָד֖וּם </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">עֲבָד֖וּם </span></span></span></td></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=מלך vs=hof prs_nu#sg|pl
''')[0:335])
# Out:
#   0.35s 1 result
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Daniel 9:1">Daniel 9:1</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">אֲשֶׁ֣ר </span><span class="plain rtl  hl" ><span class="txtu hbo">הָמְלַ֔ךְ </span></span><span class="txtu hbo">עַ֖ל </span><span class="txtu hbo">מַלְכ֥וּת </span><span class="txtu hbo">כַּשְׂדִּֽים׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">הָמְלַ֔ךְ </span></span></span></td></tr></table>

# %%
A.table(A.search('''
clause
    word lex_utf8=שׁוב vt=ptca vs=qal gn=f
    # %word lex_utf8=מן
''')[0:335])
# Out:
#   0.38s 1 result
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# ...

# %% [markdown]
# .
#
# .
#
# .
#
# .

# %%
A.table(A.search('''
book book=Ezechiel
    clause
        word lex_utf8=הנה sp=intj prs_ps=p1|p2|p3
''')[0:335])
# Out:
#   0.43s 39 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">clause</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
book book=Reges_I|Reges_II
    word vt=impf lex_utf8#בקשׁ|חמם|מלך|היה|ישׁב|בוא|עשׂה|אמר|גדל|יעץ|בשׂר|מצא|שׂכל|כרת|מות|חיה|נפל|ירד|שׁוב|קום|דבר|ידע|ספר|יכל|מנה|יצא|יטב|נתן|עלה|בנה|נשׂא|שׁבע|שׁמר|עדר|עזב|שׁפט|סבב|קהל|פנה|נקה|הלך|כול|חטא|שׁמע|ירם|יצר|ירא|יסף|שׂים|אמן|פלל|ענה|שׁלח|לקח|ראה|צרר|נטה|קרע|שׁית|עבד|ירה|קרא|צוה|לחם|אכל|שׁתה|נטשׁ|שׁמם|שׂרף|בער|חלק|חסר|יקץ|אוה|יסר|נגד|בחר|עצר|מלא|נתח|נוד|כלה|מלא|מלט|משׁח|שׂפק|חזק|פקד|שׁקל|יקר|לקק|דרשׁ|חדל|נבט|נשׁק|אבה|הלל|נגח|פתה|כאב|אסר|נחשׁ|נבא|שׁלך|סור|רוץ|עוד|סתם|ברך|כזב|מעט|הרס|נסע|שׁלה|אסף|רחץ|סלח|דבק|נכה|ישׁע|עמד|יחל|תפשׂ|גור|הרג|רטשׁ|בקע|פשׁע|חכה|נהג|חשׁב|גרה|זרק|חוה|זבח|שׁכח|נצל|סמך|נשׁא|בטח|סות|חרב|קדם|שׁפך|רפא|יתר|ילד|צלל|מחה|תמם|כבה|נוע|שׁרת
''')[0:20])
# Out:
#   0.59s 0 results
# <table></table>

# %%
A.table(A.search('''
book book=Reges_I|Reges_II
    word vt=impf lex_utf8=קום
''')[0:20])
# Out:
#   0.34s 2 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=2&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="1_Kings 2:4">1_Kings 2:4</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="txtu hbo rtl"><span class="tfsechead">1_Kings</span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">יָקִ֨ים </span></span></span></td></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=חי sp=adjv
''')[0:20])
# Out:
#   0.36s 244 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
book book=Exodus
    chapter chapter=1
        clause
            word sp=verb prs_ps=p1|p2|p3
''')[0:20])
# Out:
#   0.47s 4 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">chapter</th><th class="tf">clause</th><th class="tf">word</th></tr>
# ...

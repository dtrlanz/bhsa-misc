# %%
from tf.app import use
A = use('bhsa')
F = A.TF.api.F
# Out:
# <b title="local release">TF-app:</b> <span title="rv2.3.0=#113c0687cfce3077734dac1844d244d20f4ace6f offline under ~/text-fabric-data">C:\Users\ittai_n0vs94x/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6=#bac4a9f5a2bbdede96ba6caea45e762fe88f88c5 offline under ~/text-fabric-data">C:\Users\ittai_n0vs94x/text-fabric-data/etcbc/bhsa/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2=#1ac68e976ee4a7f23eb6bb4c6f401a033d0ec169 offline under ~/text-fabric-data">C:\Users\ittai_n0vs94x/text-fabric-data/etcbc/phono/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2=#395dfe2cb69c261862fab9f0289e594a52121d5c offline under ~/text-fabric-data">C:\Users\ittai_n0vs94x/text-fabric-data/etcbc/parallels/tf/c</span>
# This is Text-Fabric 9.0.0
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 120 features found and 0 ignored
# ...

# %%
A.table(A.search('''
clause_atom
    phrase
        word sp=nmpr
        <: word lex_utf8=ה
        <: word sp=subs
''')[0:15])
# Out:
#   1.12s 420 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause_atom</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %% [markdown]
# #

# %%
A.table(A.search('''
clause
/without/
    word lex_utf8=את sp=prep
    < word sp=conj
    < word lex_utf8=את sp=prep
/-/
    word lex_utf8=נתן sp=verb
    word lex_utf8=את sp=prep
    < word lex_utf8=את sp=prep
''')[0:50])
# Out:
#   2.36s 7 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
/without/
    word lex_utf8=את sp=prep
    < word sp=conj
    < word lex_utf8=את sp=prep
/-/
    word lex_utf8=נתן sp=verb
    word lex_utf8=את sp=prep
    word lex_utf8=עם sp=prep
''')[0:50])
# Out:
#   2.36s 1 result
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=עד
    <: word lex_utf8=אשׁר
    < word sp=verb
''')[0:10])
# Out:
#   1.14s 45 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
sentence
    word lex_utf8=בעל sp=subs
''')[0:20])
# Out:
#   0.35s 167 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=14&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 14:13">Genesis 14:13</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="txtu hbo">הֵ֖ם </span><span class="plain rtl  hl" ><span class="txtu hbo">בַּעֲלֵ֥י </span></span><span class="txtu hbo">בְרִית־</span><span class="txtu hbo">אַבְרָֽם׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">בַּעֲלֵ֥י </span></span></span></td></tr>
# ...

# %%
A.table(A.search('''
sentence
    word lex_utf8=שׁאל sp=verb
''')[0:20])
# Out:
#   0.36s 177 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=24&amp;verse=47&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 24:47">Genesis 24:47</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וָ</span><span class="plain rtl  hl" ><span class="txtu hbo">אֶשְׁאַ֣ל </span></span><span class="txtu hbo">אֹתָ֗הּ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">אֶשְׁאַ֣ל </span></span></span></td></tr>
# ...

# %%
A.table(A.search('''
sentence
    word lex_utf8=היה sp=verb
    <: word lex_utf8=ב
    <: word lex_utf8=ה
    <: word lex_utf8=יום
    <: word lex_utf8=ה
''')[0:20])
# Out:
#   1.75s 52 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=כן
    word lex_utf8=דבר
''')[0:20])
# Out:
#   0.70s 23 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=איב 
''')[0:20])
# Out:
#   0.36s 283 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
sentence
    clause
        word lex_utf8=היה vt=wayq
    <: clause
        word lex_utf8=כ
        <: word vt=infc
''')[0:20])
# Out:
#   1.11s 97 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
sentence
    word lex_utf8=הנה
    < word lex_utf8=ישׁ
''')[0:20])
# Out:
#   0.70s 2 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=היה
    word lex_utf8=את sp=prep prs_ps=p2
''')[0:20])
# Out:
#   0.71s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
sentence
    word lex_utf8=עשׂה
    clause
        word lex_utf8=טוב
        word lex_utf8=ב
        <: word lex_utf8=עין st=c|a
'''))
# Out:
#   1.45s 27 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
sentence
    clause
        word lex_utf8=נתן
        < word lex_utf8=נא
'''))

# %%
A.table(A.search('''
sentence
    clause
        word lex_utf8=היה vt=infc
        word lex_utf8=אשׁה
'''))
# Out:
#   0.72s 3 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
sentence
    clause
    /without/
        word lex_utf8=ו
    /-/
        word lex_utf8=היה
        < word lex_utf8=ל
        < word lex_utf8=ל
''')[0:20])
# Out:
#   1.67s 69 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
book book=Ruth
    # %chapter chapter>36
        word
''')[0:20])
# Out:
#   0.07s 1802 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Ruth&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Ruth 1:1">Ruth 1:1</a></span></td><td class="tf rtl"><span class="rtl ubd"><span class="txtu hbo rtl"><span class="tfsechead">Ruth</span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">וַ</span></span></span></td></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=חג
    word lex_utf8=פסח
''')[0:20])
# Out:
#   0.71s 1 result
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=עשׂה
    word lex_utf8=פסח
''')[0:20])
# Out:
#   0.68s 25 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=בקשׁ
    # %word lex_utf8=יהוה|אלהים
    word lex_utf8=פנה
''')[0:20])
# Out:
#   0.71s 16 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=קרא
    word lex_utf8=מלך
''')[0:20])
# Out:
#   0.71s 40 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
sentence
    word lex_utf8=שׁכן sp=verb vs=piel
''')[0:20])
# Out:
#   0.36s 12 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=שׁם
    word lex_utf8=קדושׁ
''')[0:20])
# Out:
#   0.72s 3 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
sentence
    word lex_utf8=אשׁר
    < word lex_utf8=ו
    <: word lex_utf8=אשׁר
''')[0:20])
# Out:
#   1.16s 94 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=עשׂה
    word lex_utf8=טוב
    word lex_utf8=ישׁר
''')[0:20])
# Out:
#   1.01s 4 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=שׁמר sp=verb
    word lex_utf8=דבר nu=pl
''')[0:20])
# Out:
#   0.71s 3 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
verse
    sentence
        word lex_utf8=ו
        <: word lex_utf8=עתה
    <: sentence
''')[0:20])
# Out:
#   0.80s 255 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">sentence</th><th class="tf">word</th><th class="tf">word</th><th class="tf">sentence</th></tr>
# ...

# %%
A.table(A.search('''
sentence
    # %clause
        word lex_utf8=שׂמח
        word lex_utf8=כל
        word lex_utf8=יד
''')[0:20])
# Out:
#   1.04s 3 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=משׁלח
''')[0:20])
# Out:
#   0.35s 7 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=מעשׂה
    word lex_utf8=יד
''')[0:20])
# Out:
#   0.69s 57 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    a:word lex_utf8=כל
    b:word sp=verb ps=p1|p2|p3 vt=impf
a .prs_ps=ps. b
a .prs_nu=nu. b
''')[0:20])
# Out:
#   0.85s 22 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=כי
    <: word lex_utf8=אמר
<: clause
''')[0:20])
# Out:
#   0.73s 88 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">clause</th></tr>
# ...

# %%
A.table(A.search('''
clause
    word lex_utf8=דבר sp=verb
    word lex_utf8=על
''')[0:20])
# Out:
#   0.72s 98 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...
